# %% [markdown]
# #  Grobe Struktur:
#
# Ähnlich wie 06_22_Performance_Comparison_Results Ergebnisse auswerten. Ranking als Variable, mit der die Evaluationsmetriken berechnet werden.
# y_pred muss bei 06_21_Performance_Comparison_OptModels gespeichert werden, damit diese hier aufgerufen werden können.
# Berechnung der Rankings im jeweils ökonomisch definierten Marktgebiet pro Station für y_true und y_pred. Daraus erneute Berechnung der Evaluationsmetriken. y_true stammt aus dem processed df (jeweils für das Bundesland).
#
# y_pred gibt es für jedes Modell (meins, ARIMA, SVR, etc.) und für jede Konstellation (Gebiet, Kraftstoff).
#
# 1. Daten einlesen (processed data je Subsample)
# - daraus y_true extrahieren (je Subsample)
#
# 2. y_pred einlesen und mergen zu einer Datei
#
#
# Unterkapitel:
# Thüringen (TH)
# - E5
# - E10
# - Diesel
#
# Hessen (HE)
# - E5
# - E10
# - Diesel
#
#
#
# Modelle:
# - STGNN Modell (meins)
# - ARIMA
# - SVR
#
#
# y_pred einlesen und mergen zu einer Datei
# Evalutionsmetriken berechnen und ausgeben
#
#
# Tabelle als Ergebnis texen
# - Eine Tabelle je Kraftstoff und Gebiet

# %% [markdown]
# # 1. Import Data

# %% [markdown]
# # 2. Results

# %% [markdown]
# ## 2.1. Results, Sample: Thuringia (TH)

# %% [markdown]
# Daten einlesen (processed data für Thüringen). Daraus y_true extrahieren (je Fuel Type): y_E5_true, y_E10_true, y_Diesel_true

# %% [markdown]
# ### 2.1.1. Fuel Type: E5

# %% [markdown]
# y_pred einlesen und mergen zu einer Datei mit den Daten von oben (2.1.)
# --> y_pred aus den verschiedenen Modellen (ARIMA, SVR, etc.)
# Evalutionsmetriken berechnen (MAPE, und ausgeben. Kein MAPE (hier nicht sinnvoll!) je
#
# Tabelle als Ergebnis texen. Die Tabelle soll einen Vergleich zwischen den verschiedenen Modellen ermöglichen über die drei Zeithorizonte und die drei o.g. Metriken (vgl. Remmouche2025, Tab. 4).

# %% [markdown]
# ### 2.1.2. Fuel Type: E10

# %% [markdown]
# ### 2.1.3. Fuel Type: Diesel

# %% [markdown]
# ## 2.2. Results, Sample: Hesse (HE)

# %% [markdown]
# 1. Daten einlesen (processed data je Subsample)
# - daraus y_true extrahieren (je Subsample)

# %% [markdown]
# ### 2.2.1. Fuel Type: E5

# %% [markdown]
# ### 2.2.2. Fuel Type: E10

# %% [markdown]
# ### 2.2.3. Fuel Type: Diesel
