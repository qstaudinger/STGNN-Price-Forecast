# %% [markdown]
# # 1. Import Data

# %%
# Global Import and Directories
import sys
sys.path.append("..")
import Setup
from Setup import *
# Out:
# Current working directory: /home/qusta100/STGNN/02_Code/06_Performance_Comparison

# %% [markdown]
# In dieser Datei werden (vergleichbar mit der Code Datei 04_02 die besten Konfigurationen aus dem Tuning gespeichert).

# %% [markdown]
# # 2. Thuringia

# %% [markdown]
# ## 2.1. E5

# %% [markdown]
# ### 2.1.1 ARIMA

# %% [markdown]
# ### 2.1.2 ARIMA

# %% [markdown]
# ## 2.2. E10

# %% [markdown]
# ### 2.2.1 ARIMA

# %% [markdown]
# ### 2.2.2 ARIMA

# %% [markdown]
# ## 2.3. Diesel

# %% [markdown]
# ### 2.3.1 ARIMA

# %% [markdown]
# ### 2.3.2 ARIMA

# %% [markdown]
# # 3. Thuringia

# %% [markdown]
# ## 3.1. E5

# %% [markdown]
# ### 3.1.1 ARIMA

# %% [markdown]
# ### 3.1.2 ARIMA

# %% [markdown]
# ## 3.2. E10

# %% [markdown]
# ### 3.2.1 ARIMA

# %% [markdown]
# ### 3.2.2 ARIMA

# %% [markdown]
# ## 3.3. Diesel

# %% [markdown]
# ### 3.3.1 ARIMA

# %% [markdown]
# ### 3.3.2 ARIMA
