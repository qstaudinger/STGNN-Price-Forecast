# %% [markdown]
# Datei zur Auswertung. der 05_01 Experimente mit Fokus Hyperparameter zu verändern.
#
# Produktion von Graphen und Tabellen
#
# Unterabschnitte zur Auswertung:
#
# E5
#
# E10
#
# Diesel
